# %%
import papermill as pm
from datetime import datetime

# %%
dateTimeObj = datetime.now()
timestampStr = dateTimeObj.strftime("%Y_%m_%d")
print(timestampStr)
# Out:
# 2019_08_08

# %%
segment = "Language just in general is extremely sequential. For example, the cat sat on the mat is very different sentence from cats at than that on. Yeah order matters. Definitely so our lands are especially good at remembering what it kind of saw earlier because it forces a sequential policy over the data inputs are decided in a very ordered Manner and instead of him these kind of large conglomerates. So I guess it's both amazing and not entirely surprising that recurring neural Nets would be useful for natural language problems. It sounds like well as humans, we rely a lot on what we previously said to figure out what will say next. Let's talk a bit more than on how you're using these kind of fun variation when it comes to recurrent neural Nets is that since the output is generated one step at a time. You can kind of choose the granularity.So some bottles can choose coarser outputs, like entire word phrases or words in general in this goes all the way down to models that outputs like fights snow bytes at a time. And for us with the Uber we've been using outputs at the Character level. Okay, so you like spelling out the words for the right? Okay, and this kind of model is called Zack is a character-based Mornin and you can find out more information in the links below. So when we first talked about having you on the show, you show me this interesting graph here, right? I love to understand a little better. What is it showing us? Exactly. So this is a small visualization of our research research each row here represents different pieces of our structure data, the shading of the squares indicates how much the model actually cares about that piece of structure data and lastly each column represents a single step in our model. So as we travel across the."

# %% [markdown]
# ## Available parameters
#
# 1. `meeting_data`: path to pickled graph object of the meeting data
# 2. `segment_list`: list of segments (Using this, a graph for all these segments will be built and then ranked)

# %%
input_notebook = "keyphrase_ranker.ipynb"
output_notebook = "run_" + timestampStr + "_" + "keyphrase_ranking_output.ipynb"

# %%
nb = pm.execute_notebook(
   input_notebook,
   output_notebook,
   parameters = dict(segment_list = [segment])
)

# %%
nb
# Out:
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'tags': [],
#     'papermill': {'exception': False,
#      'start_time': '2019-08-08T13:04:49.905094',
#      'end_time': '2019-08-08T13:04:52.955442',
#      'duration': 3.050348,
#      'status': 'completed'}},
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': "[E050] Can't find model 'vendor/en_core_web_sm/en_core_web_sm-2.1.0'. It doesn't seem to be a shortcut link, a Python package or a valid path to a data directory.\n"},
#     {'output_type': 'stream',
#      'name': 'stderr',
#      'text': '[nltk_data] Downloading package wordnet to /home/shashank/nltk_data...\n[nltk_data]   Package wordnet is already up-to-date!\n'}],
# ...
