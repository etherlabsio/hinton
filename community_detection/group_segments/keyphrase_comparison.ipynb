# %%
text1 = ['Now we all know that this kind of code is there on the Google for bad idea purposes.', 'Maybe four search engine may be producing moving Docker XnumberX logger inside of them features.', 'Now we also know that there is one of the very important people who live to sign in peach.', 'If you probably have been using that party, man, are you two?', 'So there is a lot of future already being cooked up by the pool.', 'So one of the code feature is an organ system.', 'Now, give Somehow I can use the group logger and system that it would be really awesome because Google has already taken care of things like verifying off the user of twenties authenticity of the user.', 'So it is already being done there.', 'On if you notice that on our website, which is learning code online Docker, we use a piece of known as the one place you could excuse that.', 'So what I am using there is I am using some of the food Britain by Google, which is a bargain in this case, and try to incorporate that in my Vette site.', 'Now, although this enttled code is written by the Google, but I do not have to worry about what they ever turn, how they have.', 'I am just fixing a few of my meaningful and using the features off the Google that they have provided for me on how actually am I am I to do so?', 'How am I even provide new features?', 'and yes, with the help of a B A, you can do all such creatures like booking the father.', 'Every tickets are things you wanted to see me like.', 'Invent Whoville are logging in the Facebook.', 'Now there is one pulse of eating Porter now Spacy.', 'If everybody will be able to use these times of A.P.I.', 'eyes for free that are high Johnson that it can get simply, he overused or some people may use it pours a swell.', 'So there is one more concept that sometime is introduced, also known as A.P.I.', 'Now A.P.I., these again have met their baggage.', 'I signed up on the Google and take the permission of the rule the day I want to use your logger feature.'] 

text2 = ['the example of the guy is very simple.', 'Now it is something which is helping you to have a seamless connective ity.', 'You do not feel that you are getting connected with so much of the thing, but that idea is actually helping.', 'This one, hopefully always that when you try to book an airline ticket, you book it from a based website.', 'Let us say you want to fly from Jeff.', 'Tried any your jumper to Mumbai on YouTube, your favorite Indian airlines.', 'But how many times do you actually built from Indigo Airlines?', 'That you use other service is like make my trip dot com or maybe go anywhere dot com or any other self service is.', 'So how is that possible that you are looking from the third party Web site, but still you are getting a seat on the same plane?', 'The answer is A.P.I.. Now, before I move ahead and talk a little bit more about it, let us want over animation section and give you an example that you are already using off the idea.', 'Now let us try to understand what is this A.P.I.', 'and we are gonna use a simple example that you.', 'Some of you might have already beat.', 'So let me bring up my own website here.', 'Some of you might have wondered who destroyed on this website, and I would just say Woo hoo, self promotion.', 'So now let us get it on and forward that you might have seen that on this website.', 'He used a kind of a feature known a sign up.', 'I thought, this sign of features pretty common.', 'You just registered in your name, email address, pasport and then I send you information even at your email and use.', 'Click on that paper that this spending my day off, paddling the sign up Pretty common.', 'Nothing so much seed is to learn about that pretty common feature now, on the other hand, now let us bring up Google that side.', 'It writes a lot, a lot, a lot of food.'] 

text3 = ['Now what is a data database we already know what data is, but this data could be random a database is a systematic collection of data since the data in a database is organized it makes data management easy.', 'What is a database management system DBMs database management system or DBMs is a collection of programs, which enables its users to access a database manipulate data and help in the representation of data.', 'It also helps control access to the database by various users.', 'Let is discuss a few examples an online telephone directory would definitely use database management system to store data pertaining to people phone numbers and other contact details your electricity service provider is obviously using a dBMS to manage billing client related issues to handle fault data etcetera.', 'It needs to store manipulate and present data related to members their friends member activities messages advertisnts and a lot more.', 'We can provide countless numbers of examples for usage of DBMS database management systems are not a new concept and as such has been first implemented in the nineteen sixties Charles docments integrated data store or d is said to be the first DbMs in history with time database technologies evolved a aligned while usage and unexpected functional of databases have been increased immensely types of DBMs M s.'] 

text4 = ['Perhaps the biggest example of all is Google search every time you use Google search you are using a system as machine learning system that core from understanding the text of your query to adjusting the results based on your first interests such as knowing which results to when searching for Java depending anyhow whether you are a copy expert or developer.', 'Perhaps your both today machine learning immediate applications are already quite white ranging including recognition fraud detection and recommendation systems as well as texts each systems too being powerful capabilities can we apply to a wide range fields from and skin cancer detection to retail and of course in the form of self parking and self vehicles.', 'It was not that long ago that want a company or product and machine learning in a offerings.', 'He was considered novel now and my company is visiting to use machine learning and their products in some way it is rapidly becoming well an expect feature trust as we expect companies that have a website that works on your mobile device or perhaps I have a the day was come when it will be expected that our technology will be personalized and staple and self correcting as we use machine learning to make human tasks that are faster than before we can also look further into the future while machine learning can help us to test that we never could achieved on our own.', 'It is not hard to take advantage of machine learning today.', 'The Toy has gotten quite good all you need is data developers and a willingness to take the punch for our purposes.', 'I sure the definition machine learning gestures five words using data to answer questions while would not use that a short answer for an profile exam.', 'It serves a useful purpose for us asume in particular we can split the definition into two parts using data and ask for questions.']

# %%
import sys
sys.path.append("../../../ai-engine_temp/pkg/")

from graphrank.core import GraphRank
from graphrank.utils import GraphUtils, TextPreprocess
import math
from numpy import dot
from numpy.linalg import norm
from boto3 import client as boto3_client
import json
import logging
from botocore.client import Config
import numpy as np
from copy import deepcopy

gr = GraphRank()
tp = TextPreprocess()
gu = GraphUtils()


config = Config(connect_timeout=240, read_timeout=240, retries={'max_attempts': 0} )
lambda_client = boto3_client('lambda', config=config,     aws_access_key_id="AKIA5SUS6MWO4MP7KDEJ",
    aws_secret_access_key="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"
)

def get_desc(sentence):
    original_tokens, pos_tuple, filtered_pos_tuple = tp.preprocess_text(sentence, filter_by_pos=True, stop_words=False)
    word_graph = gr.build_word_graph(graph_obj=None, input_pos_text=pos_tuple, window=4, preserve_common_words=False)
    normal_keyphrase = gr.get_keyphrases(word_graph, pos_tuple, post_process=True)
    desc_keyphrase = gr.get_keyphrases(word_graph, pos_tuple, descriptive=True, post_process_descriptive=True)
    desc_keyphrase = sorted(desc_keyphrase, key=lambda kv:kv[1], reverse=True)
    normal_kp = [phrase for phrase, score in normal_keyphrase]
    desc_kp = [phrase for phrase, score in desc_keyphrase]
    
    return normal_kp, desc_kp

def cosine(vec1, vec2):
    return dot(vec1, vec2) / (norm(vec1) * norm(vec2))

def get_embeddings(input_list, req_data=None):
    #aws_config = Config(
    #    connect_timeout=60,
    ##    read_timeout=300,
    #    retries={"max_attempts": 0},
    #    region_name="us-east-1",
    #)
    #lambda_client = boto3_client("lambda", config=aws_config)
    if req_data is None:

        lambda_payload = {"body": {"text_input": input_list}}
    else:
        lambda_payload = {"body": {"request": req_data, "text_input": input_list}}

    #logger.info("Invoking lambda function")
    invoke_response = lambda_client.invoke(
        FunctionName="arn:aws:lambda:us-east-1:933389821341:function:keyphrase_ranker",
        InvocationType="RequestResponse",
        Payload=json.dumps(lambda_payload)
    )
    
    lambda_output = (
        invoke_response["Payload"].read().decode("utf8").replace("'", '"')
    )
    response = json.loads(lambda_output)
    status_code = response["statusCode"]
    response_body = response["body"]

    if status_code == 200:
        embedding_vector = np.asarray(json.loads(response_body)["embeddings"])

    else:
        embedding_vector = np.asarray(json.loads(response_body)["embeddings"])
    return embedding_vector
# Out:
# [nltk_data] Downloading package wordnet to /tmp/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /tmp/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /tmp/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
text1_keyphrase = get_desc(" ".join(text3))[0][:2]
text2_keyphrase = get_desc(" ".join(text4))[0][:2]

# %%
import time
start = time.time()
fv = {}
for key in text1_keyphrase + text2_keyphrase:
    fv[key] = get_embeddings([key])[0]
stop = time.time()
print ("time taken => ", stop - start)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-06407061bb05> in <module>
#       3 fv = {}
#       4 for key in text1_keyphrase + text2_keyphrase:
# ----> 5     fv[key] = get_embeddings([key])[0]
#       6 stop = time.time()
#       7 print ("time taken => ", stop - start)
#
# <ipython-input-2-097c9bb2b200> in get_embeddings(input_list, req_data)
#      56         FunctionName="arn:aws:lambda:us-east-1:933389821341:function:keyphrase_ranker",
#      57         InvocationType="RequestResponse",
# ---> 58         Payload=json.dumps(lambda_payload)
#      59     )
#      60
#
# ~/.pipenv/sri_gpt/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# ...

# %%
# import time
# start = time.time()
# fv = {}
# for emb in get_embeddings(text1_keyphrase + text2_keyphrase):
#     fv[0] = emb
# stop = time.time()
# print ("time taken => ", stop - start)
# Out:
# time taken =>  0.26732563972473145

# %%
scores = []
for indexa, nodea in enumerate(list(fv.keys())[:len(text1_keyphrase)]):
    for indexb, nodeb in enumerate(list(fv.keys())[len(text2_keyphrase):]):
        scores.append(cosine(fv[nodea], fv[nodeb]))

# %%
np.mean(scores)
# Out:
# /home/ether/.pipenv/sri_gpt/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/ether/.pipenv/sri_gpt/lib/python3.6/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# nan

# %%
text1_keyphrase
# Out:
# ['database management system DBMs', 'DBMS database management systems']

# %%
text2_keyphrase
# Out:
# ['machine learning system', 'data developers']

# %% [markdown]
# # keyphrase similarity with gpt

# %%
import sys
sys.path.append("../../../ai-engine_temp/pkg/")
sys.path.append("/home/arjun/BERT_Similarity_experiments/code/")
import text_preprocessing.preprocess as tp

# %%
import networkx as nx
from scipy.spatial.distance import cosine

# %%
import text_preprocessing.preprocess as tp
import numpy as np
import json
import pandas as pd
import gpt_feat_utils

gpt_model = gpt_feat_utils.GPT_Inference("/home/shubham/projects/domain_minds_v2_gpt/se/model/epoch3/", device="cuda")
#gpt_model = gpt_feat_utils.GPT_Inference("/home/arjun/gpt_experiments/engg_models/se+ether_2+1s_ep5_#2/", device="cpu")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of SpaCy & ftfy.

# %%
text1 = ['Now we all know that this kind of code is there on the Google for bad idea purposes.', 'Maybe four search engine may be producing moving Docker XnumberX logger inside of them features.', 'Now we also know that there is one of the very important people who live to sign in peach.', 'If you probably have been using that party, man, are you two?', 'So there is a lot of future already being cooked up by the pool.', 'So one of the code feature is an organ system.', 'Now, give Somehow I can use the group logger and system that it would be really awesome because Google has already taken care of things like verifying off the user of twenties authenticity of the user.', 'So it is already being done there.', 'On if you notice that on our website, which is learning code online Docker, we use a piece of known as the one place you could excuse that.', 'So what I am using there is I am using some of the food Britain by Google, which is a bargain in this case, and try to incorporate that in my Vette site.', 'Now, although this enttled code is written by the Google, but I do not have to worry about what they ever turn, how they have.', 'I am just fixing a few of my meaningful and using the features off the Google that they have provided for me on how actually am I am I to do so?', 'How am I even provide new features?', 'and yes, with the help of a B A, you can do all such creatures like booking the father.', 'Every tickets are things you wanted to see me like.', 'Invent Whoville are logging in the Facebook.', 'Now there is one pulse of eating Porter now Spacy.', 'If everybody will be able to use these times of A.P.I.', 'eyes for free that are high Johnson that it can get simply, he overused or some people may use it pours a swell.', 'So there is one more concept that sometime is introduced, also known as A.P.I.', 'Now A.P.I., these again have met their baggage.', 'I signed up on the Google and take the permission of the rule the day I want to use your logger feature.'] 

text2 = ['the example of the guy is very simple.', 'Now it is something which is helping you to have a seamless connective ity.', 'You do not feel that you are getting connected with so much of the thing, but that idea is actually helping.', 'This one, hopefully always that when you try to book an airline ticket, you book it from a based website.', 'Let us say you want to fly from Jeff.', 'Tried any your jumper to Mumbai on YouTube, your favorite Indian airlines.', 'But how many times do you actually built from Indigo Airlines?', 'That you use other service is like make my trip dot com or maybe go anywhere dot com or any other self service is.', 'So how is that possible that you are looking from the third party Web site, but still you are getting a seat on the same plane?', 'The answer is A.P.I.. Now, before I move ahead and talk a little bit more about it, let us want over animation section and give you an example that you are already using off the idea.', 'Now let us try to understand what is this A.P.I.', 'and we are gonna use a simple example that you.', 'Some of you might have already beat.', 'So let me bring up my own website here.', 'Some of you might have wondered who destroyed on this website, and I would just say Woo hoo, self promotion.', 'So now let us get it on and forward that you might have seen that on this website.', 'He used a kind of a feature known a sign up.', 'I thought, this sign of features pretty common.', 'You just registered in your name, email address, pasport and then I send you information even at your email and use.', 'Click on that paper that this spending my day off, paddling the sign up Pretty common.', 'Nothing so much seed is to learn about that pretty common feature now, on the other hand, now let us bring up Google that side.', 'It writes a lot, a lot, a lot of food.'] 

text3 = ['Now what is a data database we already know what data is, but this data could be random a database is a systematic collection of data since the data in a database is organized it makes data management easy.', 'What is a database management system DBMs database management system or DBMs is a collection of programs, which enables its users to access a database manipulate data and help in the representation of data.', 'It also helps control access to the database by various users.', 'Let is discuss a few examples an online telephone directory would definitely use database management system to store data pertaining to people phone numbers and other contact details your electricity service provider is obviously using a dBMS to manage billing client related issues to handle fault data etcetera.', 'It needs to store manipulate and present data related to members their friends member activities messages advertisnts and a lot more.', 'We can provide countless numbers of examples for usage of DBMS database management systems are not a new concept and as such has been first implemented in the nineteen sixties Charles docments integrated data store or d is said to be the first DbMs in history with time database technologies evolved a aligned while usage and unexpected functional of databases have been increased immensely types of DBMs M s.'] 

text4 = ['Perhaps the biggest example of all is Google search every time you use Google search you are using a system as machine learning system that core from understanding the text of your query to adjusting the results based on your first interests such as knowing which results to when searching for Java depending anyhow whether you are a copy expert or developer.', 'Perhaps your both today machine learning immediate applications are already quite white ranging including recognition fraud detection and recommendation systems as well as texts each systems too being powerful capabilities can we apply to a wide range fields from and skin cancer detection to retail and of course in the form of self parking and self vehicles.', 'It was not that long ago that want a company or product and machine learning in a offerings.', 'He was considered novel now and my company is visiting to use machine learning and their products in some way it is rapidly becoming well an expect feature trust as we expect companies that have a website that works on your mobile device or perhaps I have a the day was come when it will be expected that our technology will be personalized and staple and self correcting as we use machine learning to make human tasks that are faster than before we can also look further into the future while machine learning can help us to test that we never could achieved on our own.', 'It is not hard to take advantage of machine learning today.', 'The Toy has gotten quite good all you need is data developers and a willingness to take the punch for our purposes.', 'I sure the definition machine learning gestures five words using data to answer questions while would not use that a short answer for an profile exam.', 'It serves a useful purpose for us asume in particular we can split the definition into two parts using data and ask for questions.']

# %%
text0 = "This is a list of user stories that have been committed to for the next print the entire team and product owner have a solid understanding of what each of the user stories involves based on the discussions for the Sprint planning means the Sprint is a 1-2-3 week time box where the work committed to in this meant backlog is worked on through completion during the Sprint the daily scrum occurs as a stand-up meeting where the team discusses what they have completed and what they are working on as well as any blocked items the outcome of this print is a potentially shippable product potentially shippable means is a product owner can decide if it's ready to ship or if there are any additional features needed before it ships."
text1 = "The end of the Sprint a Sprint review and Sprint retrospective meeting occurs."
text2 = "The Sprint review is where the team showcases their work to the product owner and the retrospective is where the team works on what they can do to improve their process."
text3 = "Come to this tutorial series on SQL and database."

text0_fv = gpt_model.get_text_feats(text0)
text1_fv = gpt_model.get_text_feats(text1)
text2_fv = gpt_model.get_text_feats(text2)
text3_fv = gpt_model.get_text_feats(text3)

# %%
from scipy.spatial.distance import cosine

print (1 - cosine(text0_fv, text2_fv))
print (1 - cosine(text1_fv, text2_fv))
print (1 - cosine(text2_fv, text3_fv))
print (1 - cosine(text1_fv, text3_fv))

# %%
req = json.loads(json.load(open("topic_testing/sync_eng_11_26.txt","r")))

# %%
seg_list = req["body"]["segments"]

# %%
sent_list = []
for seg in seg_list:
    sent_list.extend(tp.preprocess(seg["originalText"], stop_words=False, word_tokenize=False))

# %%
keyphrase_list = []
for sent in sent_list:
    keyphrase_list.append(tp.st_get_candidate_phrases(sent))

# %%
flat_keyphrase_list = [i for j in keyphrase_list for i in j]

# %%
fkl_fv = list(map(lambda kv: gpt_model.get_text_feats(kv), flat_keyphrase_list))

# %%
nodea = "The hello world"
nodeb = "hellow whats up guys"
set([i for i in nodea.split(" ")]) & set([j for j in nodeb.split(" ")]) == True
# Out:
# False

# %%
keyphrase_graph = nx.Graph()

for index1, nodea in enumerate(flat_keyphrase_list):
    for index2, nodeb in enumerate(flat_keyphrase_list):
        if not (set([i for i in nodea.split(" ")]) & set([j for j in nodeb.split(" ")])):
            keyphrase_graph.add_edge(nodea, nodeb, weight=1-cosine(fkl_fv[index1], fkl_fv[index2]))

# %%
keyphrase_affinity = {}
for node in flat_keyphrase_list:
    edges_list = sorted(dict(keyphrase_graph[node]).items(), key=lambda kv:kv[1]["weight"], reverse=True)
    keyphrase_affinity[node] = edges_list

# %%
for node in keyphrase_affinity.keys():
    print ("Key ->>>", " ", node, "\n")
    for values in keyphrase_affinity[node][1:5]:
        print(values[0], " ", values[1]["weight"])
    print("\n\n")
# Out:
# Key ->>>   a software solution
#
# projects   0.7117041349411011
# technology   0.6941622495651245
# code   0.6890732049942017
# programs   0.6876586079597473
#
#
#
# Key ->>>   the workflow utility
#
# this method   0.7589950561523438
# this whole image source code   0.7301129102706909
# examples   0.7296871542930603
# an example   0.7224494814872742
#
#
#
# Key ->>>   the scrum process
#
# each sprint   0.7847265601158142
# agile   0.7836724519729614
# every sprint user   0.763949990272522
# waterfall development waterfall   0.751099705696106
#
#
#
# Key ->>>   people
#
# guys   0.7569499015808105
# these guys   0.7496358752250671
# times things   0.7446218729019165
# products   0.740510106086731
#
#
#
# Key ->>>   the three scrum roles
#
# these sprint   0.7076740264892578
# waterfall development waterfall   0.6910356879234314
# each sprint   0.6873103976249695
# every sprint user   0.6585901379585266
#
#
#
# Key ->>>   the three artifacts
#
# examples   0.6915366649627686
# ...

# %% [markdown]
# # K-means on sentences.

# %%
import sys
sys.path.append("/home/ether/ai-engine_temp/pkg/")
import text_preprocessing.preprocess as tp
def preprocess_text(text):
    mod_texts_unfiltered = tp.preprocess(text, stop_words=False, remove_punct=False)
    mod_texts = []
    if mod_texts_unfiltered is not None:
        for index, sent in enumerate(mod_texts_unfiltered):

            #pos_tagged_sent = tp.preprocess(sent, stop_words=False, pos=True)[1][0]
            #filtered_list = get_filtered_pos(pos_tagged_sent)
            filtered_list = tp.st_get_candidate_phrases(sent)
            if len(filtered_list)==0:
                continue
            elif True not in list(map(lambda x: len(x.split(' '))>1, filtered_list)):
#                 if len(filtered_list)>3:
#                     pass
#                 else:
#                     continue
                continue

            if len(sent.split(' ')) > 250:
                length = len(sent.split(' '))
                split1 = ' '.join([i for i in sent.split(' ')[:round(length / 2)]])
                split2 = ' '.join([i for i in sent.split(' ')[round(length / 2):]])
                mod_texts.append(split1)
                mod_texts.append(split2)
                continue

            if len(sent.split(' ')) <= 10:
                    continue

            mod_texts.append(sent)
        if len(mod_texts) <=1:
            return ""
    else:
        return ""
    
    return mod_texts
# Out:
# [nltk_data] Downloading package wordnet to /tmp/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /tmp/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /tmp/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
from sklearn.cluster import KMeans
sys.path.append("/home/arjun/BERT_Similarity_experiments/code/")
import gpt_feat_utils
gpt_model = gpt_feat_utils.GPT_Inference("/home/shubham/projects/domain_minds_v2_gpt/se/model/epoch3/", device="cpu")
# Out:
# ftfy or spacy is not installed using BERT BasicTokenizer instead of SpaCy & ftfy.

# %%
sent_list = preprocess_text(text)

# %%
#sent_list = preprocess_text(text)
sent_list_fv = [gpt_model.get_text_feats(sent) for sent in sent_list]

# %%
kmeans = KMeans(n_clusters=4, random_state=0).fit(sent_list_fv)
centers = kmeans.cluster_centers_

# %%
sent_map = {}
for index, assigned in enumerate(kmeans.labels_):
    sent_map[index] = assigned

# %%
prev = 0
print ("-------------- New Cluster --------", "\n\n")
for index, label in sorted(sent_map.items(), key=lambda kv:kv[1], reverse=False):
    if label!=prev:
        print ("-------------- New Cluster --------", "\n\n")
        prev = label
    print(sent_list[index],"\n")

# %%
from scipy.spatial.distance import cosine

dominant = []
for loc, cluster in enumerate(centers):
    dominant_temp = None
    score_temp = 0
    for index, label in sent_map.items():
        if label == loc:
            if (1-cosine(sent_list_fv[index], cluster))>score_temp:
                dominant_temp = index
    dominant.append(dominant_temp)

# %%
for pos in dominant:
    print(sent_list[pos])
# Out:
# Yeah, we should be if it is if it if the the the compass is consistent we should get it it did it again depends on what we are trying to compare right so we can compare every keep this to every other key face.
# I mean maybe when you start when you start testing or if You observe something like this just I will be just just because everything Okay and morning session can they were also discussing the word this is what the document so as you pointed out of a spirit like when I say I look I have been staring at that for XnumberX minutes you pointed out that means that I mean I am not able to infer anything and not so is not that is not that problem in general not with the approach but with the hole?
# The way I am playing currently with key face levels imperative.
# ...

# %%
mean = np.mean(sent_list_fv, axis=0)

# %%
from scipy.spatial.distance import cosine

closest = {}
for index, label in sent_map.items():
    closest[index] = (1-cosine(sent_list_fv[index], cluster))

closest_sorted = sorted(closest.items(), key= lambda kv:kv[1], reverse=True)

# %%
for sent in closest_sorted:
    print (sent_list[sent[0]])
# Out:
# I am not sure hot where to plug that in or whether it would be helpful.
# whole notion of summaries that we are thinking  But that is by actually wanted to move from segment level to something which is more understandable called a stalker alert somebody but if that is not working then we have to think of something else to make it work.
# A major thing which I wanted a clean program that I do not see any major which one.
# Even if the composition is nicely simple version are you okay for the for the whole system in the whole process took two to base your decision on a comparison that is not really reliable like like you get a similarity score, but what if you compare two cases are not related and then this similar is not Really interpretable this one question.
# ...

# %%
import numpy as np
from numpy import ndarray
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.decomposition import PCA
from typing import List


class ClusterFeatures(object):

    def __init__(
        self,
        features: ndarray,
        algorithm: str = 'kmeans',
        pca_k: int = None,
        random_state: int = 12345
    ):

        if pca_k:
            self.features = PCA(n_components=pca_k).fit_transform(features)
        else:
            self.features = features

        self.algorithm = algorithm
        self.pca_k = pca_k
        self.random_state = random_state

    def __get_model(self, k: int):
        if self.algorithm == 'gmm':
            return GaussianMixture(n_components=k, random_state=self.random_state)
        return KMeans(n_clusters=k, random_state=self.random_state)

    def __get_centroids(self, model):
        if self.algorithm == 'gmm':
            return model.means_
        return model.cluster_centers_

    def __find_closest_args(self, centroids: np.ndarray):
        centroid_min = 1e10
        cur_arg = -1
        args = {}
        used_idx = []

        for j, centroid in enumerate(centroids):

            for i, feature in enumerate(self.features):
                #value = np.linalg.norm(feature - centroid)
                value = cosine(feature, centroid)
                if value < centroid_min and i not in used_idx:
                    cur_arg = i
                    centroid_min = value

            used_idx.append(cur_arg)
            args[j] = cur_arg
            centroid_min = 1e10
            cur_arg = -1

        return args

    def cluster(self, ratio: float = 0.1) -> List[int]:
        k = 1 if ratio * len(self.features) < 1 else int(len(self.features) * ratio)
        model = self.__get_model(k).fit(self.features)
        centroids = self.__get_centroids(model)
        cluster_args = self.__find_closest_args(centroids)
        sorted_values = sorted(cluster_args.values())
        return sorted_values

    def __call__(self, ratio: float = 0.1) -> List[int]:
        return self.cluster(ratio)

# %%
def summarize(text, ratio=0.3):
    sent_list = preprocess_text(text)
    summarized_text = None
    if len(sent_list)!=0:
        sent_list_fv = [gpt_model.get_text_feats(sent) for sent in sent_list]
        cf = ClusterFeatures(np.asarray(sent_list_fv))
        res = cf.cluster(ratio)
        summarized_text = [sent_list[s] for s in res]
    return summarized_text

# %%
group = {
	"0": {
		"segment0": [
			[
				"Welcome to views from the Corner Office a conversation with private sector leaders who influence and impact the federal market views from the corner office delivers of perspective on technology acquisition and leadership issues through the lands of executives who lead the federal practices of government contractors. Now your host Jason Miller. I guess today Krishna. The CEO of Paul's secure. Welcome to the program dates. Thanks for having me. This discussion we're having today is a little different than my normal views from a corner office discussion, usually I have a government contractor, but post here is a government vendor, which is a little different. We'll get into that in a little bit. But let's start maybe at the beginning you guys do work with Federal government usually through value added sellers and other partners, but it's still good time for even if you are vendors like yourself to be in the Federal market tell me why is good time to be a government vendor. The Federal market has always been a very important market for secure, but also for other major security. When is the Federal government and the federal sector generally tends to be a pioneer in many cases and a early adapter of security solutions. Obviously there's a lot of challenges that are being faced by the and broadly speaking the commercial sector as well be it related to the increase of the types and the depth and the complexity of the threats that they're are facing what I would call inside a challenges, meaning the separation of the Federal enterprise itself from outside and an inside perspective leading to the thrust around leader trust which again, the government has been a big prominent off and then the adoption of mobile technologies and cloud for instance."
			],
			"2019-12-11T09:03:34Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"0bbbe16f-5268-4da0-91fa-20aaee090689"
		],
		"segment1": [
			[
				"Have increased the challenges as it relates to visibility and ensuring compliance in the broader sector but specifically in the federal sector as well all of these challenges and problems. Obviously result in the ability for somebody like us to solve these problems and in that in that context of fairly government and the federal sector is a very large opportunity for us. Now it's interesting you say that the government has maybe been an early adopter sometimes security companies and other technology companies. We'll say the Government's always a step behind because they are risk of diverse. They don't wanna have failure. So they wanna adopt something they know is security a little different based on the breaches. We've seen whether it's the V bridge from two thousand six the opium reach from twenty fifteen that is pushed them to be more of on the front end of security and has pushed them into the into the forefront of security. I would say and because as you know even at the National Government level at the Congress level security in various forms. Sometimes these are international threat. So to speak or the general standard security for information protection access capabilities, etcetera are all relevant the fairly government also has to be very efficient in terms of delivering and adopting new technologies like cloud and hybrid as an example or even mobile technologies. So the locking down of the areas and creating wall. The gardens is no longer practical even in the federal sector. And so the way I think about it is when people say they are risk recovers the way have a describe it is that they are risk aware as opposed to risk and in the context of being risked aware if they can be diligent intelligent about who the security providers are and ensure that they are going through the right integrations etc then the speed of delivery and deployment increases and."
			],
			"2019-12-11T09:05:34Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"2c7b6d80-8d30-4373-8477-5b574fd8fb34"
		]
	},
	"1": {
		"segment0": [
			[
				"Happening in the Security Marketplace. The rise of ransom. We talked a little bit about zero trust where is this security market though going. We're broadly you know if we have this conversation again in a year or two what's going to change about the security market specifically for the federal agencies. We spoke about feed trust happening or coming up in conversations on a more frequent basis. The way I would describe it is in the next two to three years zero trust will become much more of a prevalent deployment model in the Federal sector as well as in the commercial sector, but clearly in the subtle sector for all the reasons that we discussed two is that some of the call it the traditional requirements because networks are not gonna go away right away. So some of the traditional requirements, including things like a to dot one x take requirements etcetera will continue to evolve and a*sociated with that is end endpoint security and compliance even basic things like while I provide freedom to my end users to use any mobile device that they want. I need to have capabilities to ensure that the device is not J and so point compliance the endpoint security will be another key requirement and will become an ongoing and increasing requirement in the federal sector. We spoke about iot o t that I believe will be a very important requirement both from a visibility standpoint as well as what we would call it enforcement. So once you know what is connecting you want to take the mediation actions so that becomes an important element as well. So in that context partnerships with channel partners integrate everyone becomes critical because budgets and freedom dictated better integration more simplicity. So simplicity will be a very key trend and a requirement as well in the federal sector and last but not least continue to build."
			],
			"2019-12-11T09:36:06Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"f5a44594-8aaa-4e59-84f6-56f908f921fc"
		],
		"segment1": [
			[
				"Solutions that are hybrid that provide for additional business. I am very optimistic that the federal sector will catch on to some of the business model friends in the commercial space. Some of the ones that we discussed including subscription, including P as you go p s etcetera and all of this will need to be wrapped up in a or and automation framework providing better a**lytics and therefore better visibility to our customers. So these are some of the key requirements that we see emerging more and more and more in the federal sector and they will happen in various agencies at different speeds. But everybody seems to be trending in the same direction. It's interesting you brought up a better data a**lytics and I think that's the key thing that I see when I talked to all the time is a desire for more information but also the ability to understand and process that information do you have that problem as a security vendor where you gotta be how do you find that right balance between not just over overloading your customers with security information but helping them understand what with what it all means definitely json and I like to distinguish between information which is a slip call reporting. So and so data points or this is what happened etcetera versus insights and our focus on a**lytics is much more on the insights of hey, this is what's happening. This is what could happen and this is what you must do to protect against anything bad from happening. So while there is still a lot of value to basic reporting increasingly because of the amount of information that is being given to everyone it is more critical to move towards providing insights to our customers and that's our focus as it leads to a**lytics you brought up the fact that you guys don't sell necessarily directly to the government you worked through third party value sellers other partners talk about what the challenge."
			],
			"2019-12-11T09:38:06Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"1a79cea7-5c98-4df1-ab3a-176d6cf7ed9c"
		]
	},
	"2": {
		"segment0": [
			[
				"That brings for a Vendor who's trying to sell to the government cause that's maybe much different than how you sell the commercial world in many ways they send it this similar to how we sell into the commercial world. Although there are significant differences. So as I previously mentioned we go to a tax with our customers and indirectly development. So that's no different in the federal sector as well one of the advantages pages. Let me start with the positives of working with partners aggregate as contact this they add a lot of value to us in terms of the requirements of the federal sector meaning that they have many more feet on the street. They yeah, there a lot more intelligent so to speak and they're able to give it back to us such that we're able to build solutions that matter more to the federal sector. So that's a very important a benefit that we derived from our partner community. If you want to highlight of what could happen in the flip side the flip side is that we don't really have a awareness of visibility of everything that goes on at the end customer and sometimes we get slow down. Let's say by other vendors who might be in the process or call it the bureaucracy of the system. Sometimes and so in this particular case at least so far the positives is the negatives for us and we can take to work on how we make our relationships more efficient broader deeper etc and if anything we are trying to expand a network of partners and then we as needed can always go to our end customers and learn directly directly from them as well is that a challenge that if you call up if you have a contract with somebody and a lot of times the agency will say we only want to do with the prime do you use that a problem for you guys then they say well if we need to talk to somebody and at the agency level we have to go through our primary contract."
			],
			"2019-12-11T09:40:06Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"0647339e-0c18-4195-bff2-7275cee08ce9"
		],
		"segment1": [
			[
				"Or a partner or can you call them directly again typically that's similarly never been an issue for us because what happens in most cases is that even if any agency says they want to engage with the crime. So to speak as you highlighted the contract that we'll want take us as a subject metrics, but in many cases to the agencies that's number one number two is that over the years through a combination of a solution sprint as well as our focus on their success. We have direct access to them as well. So very I can't honestly a instance where that has been a problem for us that's good news because a lot of times that's it's more likely for small businesses we hear this. But where the prime is is so territorial. They don't wanna bring anyone else in except for the prime contract. Obviously it's it maybe different for bar or or for for a bigger company like yourself the other challenges that yeah, the other challenges with ours is some of the flow requirements you have to deal with some of the procurement and other footer requirements that or is that you deal with that anyways I guess just where I'm looking for is does does you not selling directly to the government put any extra burden or compliance issues on your shoulders that you wouldn't normally have not necessarily Json. I mean we have a relationship with the aggregate as like D solutions and makes and so our contracts are very very clear with them and then they kind of value add on the other side by either supporting us or shielding us from the idiosyncrasies of their specific relationships with the agency. So in that regard. There's actually a benefit to working with with partners, but from time to time there are acceptance in criteria etcetera that I pa*sed through. But that's completely fine because we own the entire very good almost had a time for let you go. I just want to bring up one another pieces of."
			],
			"2019-12-11T09:42:06Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"ad069637-67ef-45c8-bea5-c7dff04a091f"
		],
		"segment2": [
			[
				"This especially in the Security world. There's a big push for these innovative companies and we need to bring in all these commercial companies or that have never done business with the government and learn from them and you we've seen approaches like other transaction authorities or other transaction agreements does this what's your take on that because as you told at the very beginning and in many ways the government can can be ahead of the commercial or at least even at the commercial world where do you see this kind of balance or or this need for the the innovative company coming from or or how how's that kind of flowing down to you guys we do see the benefit of that sentiment or that requirement Jason. The way I would highlight it is that there is a meaningful call responsibility on part of all of his young or mature companies to truly understand the sector to understand your customers. So to speak right? So while you may have the other transactional priorities except etcetera. It does not remove the responsibility on the vendors to actually understand the federal factor and try to work towards satisfying and those customers in other words understand what problems are solving under understand how we will be beneficial to the fairly sector and areas such as the etcetera are call a means to an end not an end itself. So to speak. So as long as the vendors is are focused on what is the desired outcome they should be fine and on the on the left side the failure continuing to call it cross with the commercial factor. They will also allow things to be sped up in terms of adoption of latest technologies understanding of latest solutions and then obviously improving their security pastures reducing."
			],
			"2019-12-11T09:44:06Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"a4d41468-065b-49f2-854a-3493ea42f200"
		]
	},
	"3": {
		"segment0": [
			[
				"Security of the environment also increases. So those are the two key I would say the Federal is looking for us as when is that's one reason why we work with integrations and others to deliver complete. I'm am a little surprised you didn't say the budget so many people when I ask the same first question every time know is at a good time to be a federal contractor everyone says well, we have budget uncertainty or the fact is we know the budget looks like or just got a budget deal done that that affects you a lot less than maybe a more quote traditional government contractor doesn't it in many respects. Yes, although even as a vendor we would like for better predictability on the budget and the speeding up of the budget process and the allocation to them as well because we work with other bags and larger freddy contact and the degree that they are impacted we get impacted as well, the and the significance of the benefit like we to the table is we are a very diversified business. So while the federal set is a very important factor for us as a vendor. We have a very large commercial presence as well and we always trying to call it cross meaning the trends and the technologies that we've built for a commercial sector. We try to see how they can apply to the fairly sector. And to the degree that we learn about things in the federal sector. We try to take them back to the commercial sector. So in many ways we tend to be unique in that respect and so to your point about budgets etcetera we are able to diverse higher our business because of our presence in more than eighty percent of the fortune five hundred for instance that allows us to take things into the federal sector and vice versa you bring up trends and I think that's a great segue way to the next question because what are some of the trends you are seeing whether from the commercial to the federal or vice versa as you know is a very fascinating."
			],
			"2019-12-11T09:07:34Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"94b3df77-9e65-4af5-a032-8498364e95b1"
		],
		"segment1": [
			[
				"And especially in the Security space. The friends are evolving. I would say even faster than many other sectors lemme highlight a few and happy to elaborate on some as you please first one I would say is the security challenges that customers are facing. Let's start with the commercial factor are increasing at rates that has never been seen before that is further complicated i would say in many ways by the demand from the customers customers for more freedom and less control meaning that I want to be using a device wherever I am located I want you to move my applications to the cloud i want you to deploy a hybrid policy etcetera effort some of it is economics some of it is user experience some of it is simply user preference and all those things what happens is that it complicates security policy. It makes it more difficult for companies to ensure that their security posture is proper and protected. So that's one key aspect but the other side of the point is that companies have fewer resources to deploy and make useful these solutions. So on one hand the number of security solutions is growing on the other hand customers have fewer people and fewer resources to manage all this so the implication from a vendor community standpoint is make things incredibly easy to use make things more integrated don't make your customers environment your test labs. I mean those are all things that we subscribe to very deeply and strive to support customers and make their lives simpler as so speak that's that's one keeping two is with the advent of call the broadly seeking the internet of things more and more things are getting."
			],
			"2019-12-11T09:09:34Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"dfc4819e-e4e5-4ed1-8fc1-3f0ed093b9c7"
		],
		"segment2": [
			[
				"Connected to the internet. So that causes a visibility problem. So to speak for customers meaning what's connecting to my network. So what is really allowed into my networks. What should we allowed to etcetera etcetera and so that has got a lot of people thinking and worrying about what the unknown service that results in if all these things are happening. Am I compliant whether it is to my internal audit needs or external audit needs to compliant becomes a bigger and bigger issue that everybody has to to worry about so these combined with the economic challenges you mentioned budget in the federal the budgets in the commercial sector always tend to be quite tight as well and so what does cloud mean can I use the cloud and save dollars become more efficient as an example, so that at the same time increases complexity from a security sample. So these are some of the broader trends that are happening. And I think the important thing from event community standpoint is make things more simple even as you keep them secure to enable to manage these things better and give customers option don't force them into the cloud or don't save them into a data center adopt hybrid approaches and give seamless access to those custom couple interesting things I want pull the let me start with obviously the increasing number of threats. We've seen that for last year know five or ten years but the the freedom side and I think that something that the government the federal government is just starting to come to grips with that and you're seeing a big push for or citizen services user experience and things like that how did you as a security vendor kind of listen to what the government is saying and take you that into account as you're developing products and solutions freedom in this particular context comes on two fronts."
			],
			"2019-12-11T09:11:34Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"87f537ed-7266-4b8f-a0a4-51dbe9929ebc"
		]
	},
	"4": {
		"segment0": [
			[
				"Together and we can help you that integration of course or or somebody else can help you with that integration but it's just a matter of integration versus having to find new pieces or develop new technology. Yeah one of the prominent agencies is actually part of our to council and more recently actually in me of this year we hosted a customer council which included them and other commercial customers is well we do that routinely to essentially cross best practices between commercial and Federal there we went through our zero trust solutions. Not zero test plans so to speak and simply put in the approach that we take we and authenticate users which is the ident*ty problem that you highlighted devices to ensure that the devices that are connecting compliant and have the right security posture etcetera, etcetera applications to make sure that applications are authorized to be delivered in a certain way and used by the users and last but not least the networks. So users devices applications and networks are all authorized and provided access by our solutions. The combination of those will allow a customer to deploy a zero trust environment. So the more we are able to educate them in those terms and language that they already know they're getting more and more comfortable with greater trust and obviously they derive the benefits of zero trust by not having wall. The gardens and not having different security policies for inside and outside. So we've taken that approach and while the adoption in the commercial sector has been faster. I will say that the conversations and the federal sector are also accelerating do you get a sense that the reason why the conversations are accelerating is because of the technology model you mentioned earlier. How much is changing."
			],
			"2019-12-11T09:23:34Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"4c72ea12-6166-4f7c-b783-00f48da0b2bf"
		],
		"segment1": [
			[
				"The hybrid technology the hybrid cloud the hybrid T that we keep hearing about to some degree. Yes. Jason. I also think to a large degree it is the obligation of vendors such ourselves to be able to articulate these things simply to the federal factor and others and highlight how we are adding value to them rather than pushing a specific product or a point solution to them in other words if we work backwards from this concept which we define entirely customer success and doing what's right and solving their problems, including integrating with third party Vendors. We will be able to accelerate the their journey and so it's a combination of really solving the problem and then mapping it on to their particular problems and environments are there other pieces of that technology model or the or the or the business model that you're seeing that they're starting to really change as you spend more time in the federal market. So as you think about the business models themselves increasingly. I feel that is a greater awareness of business models like subscription for instance, even in the federal sector, which I will not have said a few years ago but I think this is a bleed so to speak from the commercial factor into the Federal factor where more and more customers again, either budget constrained or not thinking about subscription based models as well as agencies that offer services to other agencies thinking about pay as pay pro type models as well that requires both the aggregate and contractors is to adapt and adopt new business models which then obviously translates to us as well on our side because of the fact that we've done all of this on the commercial sector. We tried to add value to our bags and contacted by update."
			],
			"2019-12-11T09:25:34Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"114df733-174e-4eda-b0f2-b552b0e1371b"
		]
	},
	"5": {
		"segment0": [
			[
				"First from a administrator perspective, meaning the person that is setting policies setting up infrastructure applications, etcetera. The freedom that we are trying to enable for them is how do I kinda of create investment protection for what you've already bought while you stand into new deployment. Let's say in the cloud as an example, how do I give you freedom to adopt applications that are modern than that may be delivered from the cloud without compromising what you have built over the years in your data centers how do I policies security practices are consistent between the cloud and the data center. So that's broadly called hybrid. I or hybrid security in this particular context. So that's a level of freedom we need to provide to everybody including the federal sector because that's becoming an increasingly important requirement. Obviously there's an economic dimension to budget. I dimension to it as well on the other side I would call them end users requiring freedom and that could be be it use my mobile device be it use my system from anywhere be it local be remote in another country without compromising my security posture and giving me freedom to be productive freedom. Essentially equates to simplicity which then allows you to more productive what we have done is on the end user side we have client software that is identical across all platforms. So whether you take windows mac linux etc. What we ensure is that the user experience and all of those platforms is identical. So when a customer or end users which is from one platform to another they don't have to learn things that's."
			],
			"2019-12-11T09:13:34Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"d5dfd7d8-a790-42fb-beb6-d1a07278dc80"
		],
		"segment1": [
			[
				"A very important element of giving them freedom to choose whatever platform. They wanna use then obviously there is the integration into the platform itself where they don't feel like they're using separate and new technology. So in other words what we have done is on all operating systems we have a approach which we call a workspace in fact, many customers in the Federal sector use this particular product which allows it and user to use any device or their choosing but as long as they have the workspace because the workspace is protected. So you're separating always the person from the business that also is an option that we give to the federal sector where they able to not have to procure a lot more devices then they absolutely need to and then worry about how they lock them down so that's another form of freedom that both types of freedom that we just discussed let's take a quick break when come back we can jump into some of those other things you talked about in terms of trends. My guest is to Doc Krishna the CEO of post. I'm and you're listening the interviews from a corner office on Federal news radio part of the Federal news network. Welcome back your listing interviews corner office on Federal news radio part of the Federal news network. I'm my guess is Doc Krishna the CEO of post now before break we're talking about some of the trends and one of the trends you brought up that I wanna come touch pod is the most iot o T connected devices internet of things whatever. We're gonna call it these days and so much of it as you said causes is a visibility problem as agencies are putting more things online. They have to be able to protect and know that they're there walk me through that challenge of if you can't see it you can't protect it. This is becoming increasingly relevant thing both in the commercial sector as well as in the fairly sector. I cannot tell you how many times I would go to a customer for him instance, the conversation goes like."
			],
			"2019-12-11T09:15:34Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"27269849-33cd-441d-9134-74a75ba6c110"
		]
	},
	"6": {
		"segment0": [
			[
				"Element I should say becomes incredibly difficult. So that's where we kind of learned our ropes so to speak on working with partners and being dedicated to partners and we carried that forward into the federal second we've been doing that for the better part of ten years many times when I talk to what I talked to for the show there they had a federal very senior vice President maybe their President very rarely do I get actually the CEO especially for a large business like yourselves. So what's a day to day CEO like you get up in the morning and you're checking your email and what else like give it a typical day for you at typical day for me is a series of meetings some meetings with our go to market team. So I when I wake up generally try to touch base with the teams in Europe where it's already mid day for instance for them that gives me a head start on what's happening on Europe and a typical drive to the workplace if I'm not traveling to a customer or a partner would involve touching base with the a series of my teammates server whether it be my marketing counterpart my c f o except I just quick touch base on how things are going what happening what needs to be done etcetera etcetera and then one time at work. I like to describe my job as trying to enable others and eliminate roadblocks so to that and I spend a lot of time in. Let's say a budget meeting or planning meeting or sometimes we prepare for our external boards and investors to to call it update them on the health of the business the progress of the business etcetera, but also tried to spend at least thirty percent of my time. If not more with customers and partners and I also tend to spend a lot of time with my employees because at the end of the day if I can have a satisfied employee base i know my customers will be taken care of this is we get to the part of the show this one of my favorite parts because I get to learn something about you."
			],
			"2019-12-11T09:32:06Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"300e5bbe-3678-46ab-b084-9ac31f0079f8"
		],
		"segment1": [
			[
				"That maybe most people don't know or that's outside of this federal commercial cyber cybersecurity world what's maybe one thing about yourself that you like to do outside of work or that something different about you that maybe some people don't know that's the interesting question based I would say I'm not doing much of it now but when I was quite a bit younger I to him C above and his three bus and so a team of us three to four of us would go from one city to another and essentially compete or SPA with other teams in terms of who new that see we are the best. So it's similar to like jeopardy and others, but it's not as structured and it was much more free flowing we used to enjoy that a lot because there was a certain camaraderie alternate and a certain level of creativity and exploration involved in it. So that is something that I don't think a lot of people know about me. So did you ever go out for jeopardy. No not not for jeopardy here not not yet at least right not yet yet that least yes. That's a more optimistic and and was there a part of the trivial issue that you were special specialized in were you more about geography versus something else who knows I was more focused than history and sports so both and history. Alright very cool very interesting. Alright well let's take another the quick break when come back we can complete our conversation. I guess is dot call Krishna. The CEO post here I'm Miller and you're listening to view from recorder office on Federal news radio part of the Federal news network. Welcome back to listening interviews from a corner office on Federal news radio part of the Federal news network. I mean host Jason Miller my guest is Krishna. The CEO E O secure now before break we're talking and getting you and a little bit more about post you guys are security vendor you guys or seen all the trends that are."
			],
			"2019-12-11T09:34:06Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"cd1b415c-6868-4ef7-9859-d833700cbe5e"
		]
	},
	"7": {
		"segment0": [
			[
				"Risk improving their visibility and obviously reducing their total as it relates to security by giving their end users more freedom to be productive in an economical fashion. Alright very nice. This is a bit a fascinating in conversation. I really do appreciate your time. So may take my guest dot krishna the CEO of poster. Thank you so much for your time. Thank you again, Jason. I'm jeez Miller and you'd been most the interviews from a recorder office on Federal news radio part of the Federal news network. You've been listening to views from the corner office on Federal news radio part of the Federal news network tune Fridays at Noon or subscribed to this show on Itunes or podcast past one."
			],
			"2019-12-11T09:46:06Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"57a8737d-0909-4090-95d8-b38f0ceed405"
		]
	},
	"8": {
		"segment0": [
			[
				"This generally ask a customer how many devices do you think are at any point in time connected to your network who was connecting and connecting to your network and oftentimes. Let's say they come up with an answer like five thousand and within a few weeks of running some software and identifying what's getting connected to them we t find that they're off by a factor of two or three and in some cases in factor of ten in many cases. So what happens is that that really creates a aha moment for them saying I if I don't even know what's trying to connect to my network how will I ever be able to protect it and that is really the visibility challenge and that's greatly exacerbated by the the whole I o t trend or as you said connected internet where on one hand. I say it is very good and very productive for all of these devices to be connected to the internet. Why simply because it makes administrators life in terms of understanding various forms of connections connectivity and usage that much more simpler, but with that kind of freedom comes the complexity of what is the security capabilities of these devices they're running the right types of software how can I attach policy to that all those things become very important. And that's where the first step is to understand what is being connected to the network and then a**lyze the visibility challenge and again, this has become a very top of my topic for both commercial as well as the Federal factor. I know in the Federal sector. They're using the continuous diagnostics and mitigation or C p m program and and that has played a big role and understanding me what's on agencies networks at the same time know to secure those devices they may know that they're there."
			],
			"2019-12-11T09:17:34Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"53cba42d-1ce4-4971-9b6e-b28cb590ef6e"
		],
		"segment1": [
			[
				"Think that that leaves us down the path of another kind of related trend which is why zero trust is getting so much attention in the federal market and and I know you guys are in the zero trust world too. But let's walk me through a little bit zero trust we know that umbrella. It's a framework. It's not aiming one technology, but what are you seen from when you talk to agency about zero trust and it is becoming increasingly at top of mind topic traditional way of looking at security was you had an enterprise boundary or a parameter call it a wall garden every bit of traffic that comes from outside the enterprise per was deemed unsafe for by definition and therefore had to be protected and authorized on the everything that was inside the parameter was deemed secure and should have free access increasingly what's happening and this happened a lot more in the commercial factor is that more and more threat starting from inside the network and think of a very simple case I'm working on my computer at home. I get infected by something happening on the internet. I come inside the network parameter meaning inside my office. I'll open up my laptop and I have the danger of interacting the entire system. So that's becoming increasingly prevalent and there are many more sophisticated ways of doing that, but I'm giving you a very basic example that is leading to this notion of hey, I icon. I can't trust traffic coming from the outside nor should I trust anything that inside leading to the concept of zero trust while on one hand everybody's beginning to be aligned on trust. What it also creates is what is the best way most economical way and simply put the most secure way of addressing this zero trust challenge and that's what when is like us and others."
			],
			"2019-12-11T09:19:34Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"ad81db93-68ab-4919-88cc-d81bc81b4c67"
		],
		"segment2": [
			[
				"Are attempting thing to do both for the commercial sector as well as the federal factor. When you talk to your federal clients when you work with your your partners is you ever trust one of those things that just comes up constantly or is it something that's maybe more that that just starting to come up now or last six months. I would say it is increasingly coming up Jason and I would say the number of asks or mentions is actually accelerating is bit probably the best way to categorize it and at the same time though nobody's really doing zero trust at least from my perspective the people I've talked to I think a lot of people are are just talking about it. You is that something near seeing or do you you actually see the pieces being put in place to create that zero trust environment. I would actually humbly submit that we and some others are actually addressing zero trust in a very comprehensive way rights on the get go and increasingly as our portfolio use continue to evolve this support the freedom requirement that we spoke about both for administrators and end users of what we're really doing now is mapping what we do through the concept of zero trust. So in other words. This is not a case of a new concept coming up and then everybody catching up to it. We are all figuring out how to reinforce and rename size what we do in the zero trust framework. So in that trigger regard i would say the solution from us and some others are actually closer to customer needs then simply a concept that's interesting because you hear so much to talk about it and never says well there's the the ident*ty management piece and then there's the you know hardware a*set so for us that management piece and these kind of all these pieces and parts that fit on the umbrella, but that's good to hear that you know it's it's it's almost like the the message from Vendors like yourselves is that hey, the pieces are there you just as agency maybe just have to put them."
			],
			"2019-12-11T09:21:34Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"d3c4b40c-6348-43f7-bb37-a0c7d53a36ac"
		]
	},
	"9": {
		"segment0": [
			[
				"You're listening to interviews from a corner Office on Federal news radio part of the Federal news network. I'm your host Jason my guest is Krishna the CEO post no see before break we're talking about the transition and some of the the difference between being a a vendor and the marketplace versus a contractor. So let's get into little more deep depth about what whole here is you role in the federal market and as well as your role as CEO talk a little bit about your company S c e o obviously my main focus is customer success as I previously defined regardless of the sector that the customers are in whether be the federal factor or in the commercial sector. We have a strategy within the company of full fulfilling almost everything we sell through our partners partners are a lot of value to customers. They provide direct touch to customers etcetera, but equally we believe in maintaining direct touch and contacts with as many customers as we possibly can almost every agency in the Federal sector is our customer as well granted through our and our partners some of the agencies are actually on our customer council. So we get a direct connection and connectivity with these customers. We're able to have conversations about trends highlight what's happening in the commercial sector learn from them as to their aspirations for their agencies and others and then work with our partners in terms of responding to larger r F p full fulfilling etcetera. So the way I would describe it is we have a direct touch model with the end customer and a indirect full element model with the likes of loyalty solutions and and others walk me through what a typical of you will bid would look like for company like here is vendor versus a contractor you your partners with a a systems integrated do they call you up and say hey we."
			],
			"2019-12-11T09:28:06Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"ce7285d2-a9e5-4937-8fbb-c4c87a24badd"
		],
		"segment1": [
			[
				"Partially walk me a little bit just through maybe something that's typical I give you a couple of scenarios that are typical and one is customers has already deployed a solution to both our touch and the partners touch over the years and they're looking at. Let's say expanding slash modernizing right in those cases. It's a much simpler programming model because we are already in the environment and the customers looking to expand it still comes to us through the resource slash aggregate slash contractor, but it's a fairly straightforward. Then so to speak in other cases the contract that might have and a field. Let's call it a hey, the agencies looking for increase then improved visibility. We been asked to respond with specific vendor solutions can you work with us on responding and creating a very comprehensive response to the agency. So that is the other form which is much more elongated at some level but we go through that process as well and in many cases with our partner as well as the agencies need take so those are the two typical models. It's it's rarely something where out of the blue they come to us and say hey do you have something like this. It's interesting. There's the two kind of paths you guys go down on so kind of get in front of the customer and and work with with your partners. How different is that then just bidding on your own did you guys ever think about maybe we would just sell directly to the government or have you always gone down the path of partners and value added resources. We've always gone down the path of partners and value every resources you could say that some degree that comes from a commercial heritage because in the commercial space. We are in every major geography. We have over twenty thousand customers so providing touch to every one of them."
			],
			"2019-12-11T09:30:06Z",
			"716067a60a1a4034abc49a12ecafb39b",
			"25b12467-62ab-447c-a5c3-79b64c7b78f4"
		]
	}
}

# %%
text_list = []
for groupid in group.keys():
    #print ("groupid: ", groupid)
    temp = []
    for seg in [group[groupid][x][0] for x in group[groupid]]:
        temp.append(seg[0])
    text_list.append(" ".join(temp))

    print()

# %%
from scipy.spatial.distance import cosine
summarized_list = []
for index, text in enumerate(text_list):
    print (text)
    print ("------summarized text------","\n\n")
    summarized = summarize(text, ratio=0.2)
    if summarized!=None:
        summarized_list.append(summarized)
        print (*summarized, sep="\n",end="\n\n")
# Out:
# Welcome to views from the Corner Office a conversation with private sector leaders who influence and impact the federal market views from the corner office delivers of perspective on technology acquisition and leadership issues through the lands of executives who lead the federal practices of government contractors. Now your host Jason Miller. I guess today Krishna. The CEO of Paul's secure. Welcome to the program dates. Thanks for having me. This discussion we're having today is a little different than my normal views from a corner office discussion, usually I have a government contractor, but post here is a government vendor, which is a little different. We'll get into that in a little bit. But let's start maybe at the beginning you guys do work with Federal government usually through value added sellers and other partners, but it's still good time for even if you are vendors like yourself to be in the Federal market tell me why is good time to be a government vendor. The Federal m
# ...

# %%
text_dict = {
            "segment0": [
                [
                    "How we have in groups? And as a filtration process we check weather. Is add any Group which has more than one segment? "
                ],
                "2019-12-02T06:35:23Z",
                "fb52cb663aec4795aee38ccfd904d315",
                "b7d7f0b747d44094a3809d0bd93e48c8"
            ],
            "segment1": [
                [
                    "So if that is any Group, which has more than one segment, then we remove all the groups which has only one single segment. This was just too. "
                ],
                "2019-12-02T06:35:40Z",
                "fb52cb663aec4795aee38ccfd904d315",
                "f03e765b732448b1ba2c1372b1fe5952"
            ],
            "segment2": [
                [
                    "to remove "
                ],
                "2019-12-02T06:35:58Z",
                "fb52cb663aec4795aee38ccfd904d315",
                "e73b9748e1d04a02bc5571b59f284a05"
            ],
            "segment3": [
                [
                    "The segments because we don't have any way to currently we don't have any way to save other single segment is either contextually relevant or not. So until we have something we just wanted to remove this for example, like if you have a 76 or 70s called most of the segments would give group but there is a very high chance that there will be lot of dangling segments. In this case. The dangling segments are either it went into the wrong Community or it gets gets removed in pre-processing. So the pre-processing segments are the preprocessor segments or sentences, which got removed in the initial stage. They would get added just after forming communities. So that even pre-process segments plays a part in here. "
                ],
                "2019-12-02T06:36:06Z",
                "fb52cb663aec4795aee38ccfd904d315",
                "49e579ffc0864590a44e87259a5fbf12"
            ],
            "segment4": [
                [
                    "If that is no groups, which has more than one segment in it, then we don't remove groups through any groups because obviously all the groups in the whole final result only once in the segment. So it's more like fall that victims. Which is same as fall back to terms, it gives top 5 result. "
                ],
                "2019-12-02T06:37:04Z",
                "fb52cb663aec4795aee38ccfd904d315",
                "5c856f4ba3c44a5e8b602dde5b433d8e"
            ],
            "segment5": [
                [
                    "It gives top fill groups that each group is nothing but a segment so I'm then we take each group and then we compare it with the mind and then rank them and then send it to the if a service. So if for any case the graph computation or the grouping the community algorithm fails at some point then we fall back to The fall back to pins would be simple just take all the segments which are present in the request and then get the same feature because for them and score it across all the mines expect to - and then rank them order them and then push on the top five. "
                ],
                "2019-12-02T06:37:34Z",
                "fb52cb663aec4795aee38ccfd904d315",
                "26271fda00904852a66953cef9eab62d"
            ]
        }

text_list = [" ".join(list(map(lambda kv:" ".join(kv[0]), text_dict.values())))]

# %%
for seg in summarized_list:
    print (" ".join(seg), "\n\n")

# %%
import pickle
mind = list(pickle.load(open("/home/ether/hdd/ether/gpt_domain_minds/se/mind.pkl","rb"))['sentence'].values())

# %%
mind_fv = [gpt_model.get_text_feats(x) for x in mind]

# %%
mind[0]
# Out:
# 'You can use this bundle while developing apps using command line or by configuring it using webpack'

# %%
chosen_sentence_norm = []
for mind_index in range(len(mind)):
    best_score = 100000
    chosen_sentence_temp = None
    for index, fv in enumerate(sent_list_fv):
        score = np.linalg.norm(fv - mind_fv[mind_index])
        #score = cosine(fv, mind_fv[mind_index])
        if score < best_score:
            best_score = score
            chosen_sentence_temp = sent_list[index]
    chosen_sentence_norm.append(chosen_sentence_temp)

# %%
chosen_sentence_cosine = []
for mind_index in range(len(mind)):
    best_score = 100000
    chosen_sentence_temp = None
    for index, fv in enumerate(sent_list_fv):
        #score = np.linalg.norm(fv - mind_fv[mind_index])
        score = cosine(fv, mind_fv[mind_index])
        if score < best_score:
            best_score = score
            chosen_sentence_temp = sent_list[index]
    chosen_sentence_cosine.append(chosen_sentence_temp)

# %%
for index, sent in enumerate(chosen_sentence):
    print ("Mind Sentence:  ", mind[index], "\n\n Most similar based on cosine =>", chosen_sentence_cosine[index],"\n\n Most similar based on norm =>", chosen_sentence_norm[index], "\n\n\n\n")
# Out:
# Mind Sentence:   You can use this bundle while developing apps using command line or by configuring it using webpack
#
#  Most similar based on cosine => Like we can do that but it is very very difficult because huge standard.
#
#  Most similar based on norm => Like we can do that but it is very very difficult because huge standard.
#
#
#
#
# Mind Sentence:   This command should start all dependent processes and yield when they are fully initialized
#
#  Most similar based on cosine => Once it is done.
#
#  Most similar based on norm => Once it is done.
#
#
#
#
# Mind Sentence:   The functions runtime handles hosting and scaling your code in response to events or triggers that range from HTTP requests to timers messages database updates and more
#
#  Most similar based on cosine => It is easy like adding the listeners and listening to it.
#
#  Most similar based on norm => It is already discussed.
#
#
#
#
# Mind Sentence:   It supports backing up from all storage engines
#
# ...

# %% [markdown]
# # Np similarity.

# %%
req = json.load(open("validation_tests/set_1/set_1.txt","r"))
if isinstance(req, str):
    req = json.loads(req)["body"]
else:
    req = req["body"]

# %%
req["segments"] = sorted(req['segments'], key=lambda kv:kv['startTime'])
for index, seg in enumerate(req["segments"]):
    req["segments"][index]["originalText"] = " ".join(preprocess_text(seg["originalText"]))
segments_map = {}
for index, seg in enumerate(req["segments"]):
    if seg["originalText"] != "":
        segments_map[seg['id']] = seg
        segments_map[seg['id']]["order"] = index
text = list(map(lambda seg: (seg["originalText"], seg["id"]), [segment for segment in req['segments'] if segment["originalText"]!=""]))
seg_list = [sent for sent, id  in text]
segid_list = [id for sent, id in text]
sent_list = list(map(lambda seg, segid:([sent + ". " for sent in seg.split(". ")],segid), seg_list, segid_list))
sent_list = [(sent, segid) for seg, segid in sent_list for sent in seg]
